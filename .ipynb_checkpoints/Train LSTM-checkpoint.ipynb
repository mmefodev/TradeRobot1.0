# %%
import numpy as np
import pandas as pd
import os
import datetime as dt

# %%
# Creating list of pathes to files
path = 'D:\\Python Projects\\Stonks\\Tinkoff Online Trading\\Data'

file_paths = []
for root, dirs, files in os.walk(path, topdown = False):
    for name in files:
        if '3 sec' in name:
            file_paths.append(os.path.join(root, name))

# %%
# Cooking dataset for predicting
df = pd.read_csv(file_paths[0])

# Creating shifted time columns, so we know what samples will have correct max and min prices
df.iloc[:, 0] = pd.to_datetime(df.iloc[:, 0])

# Adding shifted time to check time correctness of sample
df['Time_shift1'] = df.iloc[:, 0].shift(-20)
df['Time_shift2'] = df.iloc[:, 0].shift(-40)
df['Time_shift3'] = df.iloc[:, 0].shift(-60)

# Adding future prices to be able to classify sample
future_prices = pd.concat([df.iloc[:, 1:-3:41].shift(-20), 
                           df.iloc[:, 1:-3:41].shift(-40), 
                           df.iloc[:, 1:-3:41].shift(-60)], axis=1
                         )
df['Max_3min'] = np.max(future_prices, axis=1)
df['Min_3min'] = np.min(future_prices, axis=1)

# Filter good samples
df = df[(df.iloc[:, 821] - df.iloc[:, 0] < dt.timedelta(minutes=1, seconds=1)) &
        (df.iloc[:, 821] - df.iloc[:, 0] > dt.timedelta(minutes=0, seconds=59)) &
        (df.iloc[:, 822] - df.iloc[:, 0] < dt.timedelta(minutes=2, seconds=1)) &
        (df.iloc[:, 822] - df.iloc[:, 0] > dt.timedelta(minutes=1, seconds=59)) &
        (df.iloc[:, 823] - df.iloc[:, 0] < dt.timedelta(minutes=3, seconds=1)) &
        (df.iloc[:, 823] - df.iloc[:, 0] > dt.timedelta(minutes=2, seconds=59))
       ]
df = df.dropna()

# %%
# Filtering useful columns
columns = [column for i, column in enumerate(df.columns) if not (('Time_shift' in column) | (i == 0))]
df = df[columns]
#df = df.astype('float32')

# Renaming columns to group them
new_columns = []
j = 0
group_size = 3
for i, col in enumerate(columns):
    part_num = i//41
    if 'min' in col:
        new_columns.append(col)
    elif i%41 == 0:
        new_columns.append('price'+str(part_num))
    else:
        group_num = (i - part_num - 1) % 20 // group_size
        is_ask = (i - part_num - 1) // 20 % 2
        if is_ask:
            new_columns.append('ask'+str(group_num)+'_'+str(part_num))
        else: 
            new_columns.append('bid'+str(group_num)+'_'+str(part_num))

df.columns = new_columns
df = df.groupby(df.columns, axis=1).sum()

# %%
# Out:
#        Max_3min  Min_3min  ask0_0  ask0_1  ask0_10  ask0_11  ask0_12  ask0_13  \
# 0        152.09     151.7    88.0    88.0     88.0     88.0     88.0     90.0
# 1        152.09     151.7    88.0    88.0     88.0     88.0     90.0    158.0
# 2        152.09     151.7    88.0    88.0     88.0     90.0    158.0    158.0
# 3        152.09     151.7    88.0    88.0     90.0    158.0    158.0    158.0
# 4        152.09     151.7    88.0    88.0    158.0    158.0    158.0    164.0
# ...         ...       ...     ...     ...      ...      ...      ...      ...
# 11916    146.51     145.9    72.0    72.0     72.0     72.0     72.0     72.0
# 11917    146.51     145.9    72.0    72.0     72.0     72.0     72.0     73.0
# 11918    146.51     145.9    72.0    72.0     72.0     72.0     73.0     73.0
# 11919    146.51     145.9    72.0    72.0     72.0     73.0     73.0     73.0
# 11920    146.51     145.9    72.0    72.0     73.0     73.0     73.0     73.0
#
#        ask0_14  ask0_15  ...  price18  price19  price2  price3  price4  \
# 0        158.0    158.0  ...   151.70   151.70  151.70  151.70  151.70
# 1        158.0    158.0  ...   151.70   151.70  151.70  151.70  151.70
# 2        158.0    164.0  ...   151.70   151.70  151.70  151.70  151.70
# 3        164.0    158.0  ...   151.70   151.70  151.70  151.70  151.70
# 4        158.0    158.0  ...   151.70   151.70  151.70  151.70  151.70
# ...        ...      ...  ...      ...      ...     ...     ...     ...
# 11916     73.0     73.0  ...   146.51   146.51  146.51  146.51  146.51
# 11917     73.0     73.0  ...   146.51   146.51  146.51  146.51  146.51
# 11918     73.0     73.0  ...   146.51   146.51  146.51  146.51  146.51
# 11919     73.0     73.0  ...   146.51   146.51  146.51  146.51  146.51
# 11920     73.0     73.0  ...   146.51   146.51  146.51  146.51  146.51
#
#        price5  price6  price7  price8  price9
# 0      151.70  151.70  151.70  151.70  151.70
# 1      151.70  151.70  151.70  151.70  151.70
# 2      151.70  151.70  151.70  151.70  151.70
# 3      151.70  151.70  151.70  151.70  151.70
# 4      151.70  151.70  151.70  151.70  151.70
# ...       ...     ...     ...     ...     ...
# 11916  146.51  146.51  146.51  146.51  146.51
# 11917  146.51  146.51  146.51  146.51  146.51
# 11918  146.51  146.51  146.51  146.51  146.51
# 11919  146.51  146.51  146.51  146.51  146.51
# 11920  146.51  146.51  146.51  146.51  146.51
#
# [11921 rows x 302 columns]

# %%
new_columns
# Out:
# ['price0',
#  'bid0_0',
#  'bid0_0',
#  'bid0_0',
#  'bid1_0',
#  'bid1_0',
#  'bid1_0',
#  'bid2_0',
#  'bid2_0',
#  'bid2_0',
#  'bid3_0',
#  'bid3_0',
#  'bid3_0',
#  'bid4_0',
#  'bid4_0',
#  'bid4_0',
#  'bid5_0',
#  'bid5_0',
#  'bid5_0',
#  'bid6_0',
#  'bid6_0',
#  'ask0_0',
#  'ask0_0',
#  'ask0_0',
#  'ask1_0',
#  'ask1_0',
#  'ask1_0',
#  'ask2_0',
#  'ask2_0',
#  'ask2_0',
#  'ask3_0',
#  'ask3_0',
#  'ask3_0',
#  'ask4_0',
#  'ask4_0',
#  'ask4_0',
#  'ask5_0',
#  'ask5_0',
#  'ask5_0',
#  'ask6_0',
#  'ask6_0',
#  'price1',
#  'bid0_1',
#  'bid0_1',
#  'bid0_1',
#  'bid1_1',
#  'bid1_1',
#  'bid1_1',
#  'bid2_1',
#  'bid2_1',
#  'bid2_1',
#  'bid3_1',
#  'bid3_1',
#  'bid3_1',
#  'bid4_1',
#  'bid4_1',
#  'bid4_1',
#  'bid5_1',
#  'bid5_1',
#  'bid5_1',
#  'bid6_1',
#  'bid6_1',
#  'ask0_1',
#  'ask0_1',
#  'ask0_1',
#  'ask1_1',
#  'ask1_1',
#  'ask1_1',
#  'ask2_1',
#  'ask2_1',
#  'ask2_1',
#  'ask3_1',
#  'ask3_1',
#  'ask3_1',
#  'ask4_1',
#  'ask4_1',
#  'ask4_1',
#  'ask5_1',
#  'ask5_1',
#  'ask5_1',
#  'ask6_1',
#  'ask6_1',
#  'price2',
#  'bid0_2',
#  'bid0_2',
#  'bid0_2',
#  'bid1_2',
#  'bid1_2',
#  'bid1_2',
#  'bid2_2',
#  'bid2_2',
#  'bid2_2',
#  'bid3_2',
#  'bid3_2',
#  'bid3_2',
#  'bid4_2',
#  'bid4_2',
#  'bid4_2',
#  'bid5_2',
#  'bid5_2',
#  'bid5_2',
#  'bid6_2',
#  'bid6_2',
#  'ask0_2',
#  'ask0_2',
#  'ask0_2',
#  'ask1_2',
#  'ask1_2',
#  'ask1_2',
#  'ask2_2',
#  'ask2_2',
#  'ask2_2',
#  'ask3_2',
#  'ask3_2',
#  'ask3_2',
#  'ask4_2',
#  'ask4_2',
#  'ask4_2',
#  'ask5_2',
#  'ask5_2',
#  'ask5_2',
#  'ask6_2',
#  'ask6_2',
#  'price3',
#  'bid0_3',
#  'bid0_3',
#  'bid0_3',
#  'bid1_3',
#  'bid1_3',
#  'bid1_3',
#  'bid2_3',
#  'bid2_3',
#  'bid2_3',
#  'bid3_3',
#  'bid3_3',
#  'bid3_3',
#  'bid4_3',
#  'bid4_3',
#  'bid4_3',
#  'bid5_3',
#  'bid5_3',
#  'bid5_3',
#  'bid6_3',
#  'bid6_3',
#  'ask0_3',
#  'ask0_3',
#  'ask0_3',
#  'ask1_3',
#  'ask1_3',
#  'ask1_3',
#  'ask2_3',
#  'ask2_3',
#  'ask2_3',
#  'ask3_3',
#  'ask3_3',
#  'ask3_3',
#  'ask4_3',
#  'ask4_3',
#  'ask4_3',
#  'ask5_3',
#  'ask5_3',
#  'ask5_3',
#  'ask6_3',
#  'ask6_3',
#  'price4',
#  'bid0_4',
#  'bid0_4',
#  'bid0_4',
#  'bid1_4',
#  'bid1_4',
#  'bid1_4',
#  'bid2_4',
#  'bid2_4',
#  'bid2_4',
#  'bid3_4',
#  'bid3_4',
#  'bid3_4',
#  'bid4_4',
#  'bid4_4',
#  'bid4_4',
#  'bid5_4',
#  'bid5_4',
#  'bid5_4',
#  'bid6_4',
#  'bid6_4',
#  'ask0_4',
#  'ask0_4',
#  'ask0_4',
#  'ask1_4',
#  'ask1_4',
#  'ask1_4',
#  'ask2_4',
#  'ask2_4',
#  'ask2_4',
#  'ask3_4',
#  'ask3_4',
#  'ask3_4',
#  'ask4_4',
#  'ask4_4',
#  'ask4_4',
#  'ask5_4',
#  'ask5_4',
#  'ask5_4',
#  'ask6_4',
#  'ask6_4',
#  'price5',
#  'bid0_5',
#  'bid0_5',
#  'bid0_5',
#  'bid1_5',
#  'bid1_5',
#  'bid1_5',
#  'bid2_5',
#  'bid2_5',
#  'bid2_5',
#  'bid3_5',
#  'bid3_5',
#  'bid3_5',
#  'bid4_5',
#  'bid4_5',
#  'bid4_5',
#  'bid5_5',
#  'bid5_5',
#  'bid5_5',
#  'bid6_5',
#  'bid6_5',
#  'ask0_5',
#  'ask0_5',
#  'ask0_5',
#  'ask1_5',
#  'ask1_5',
#  'ask1_5',
#  'ask2_5',
#  'ask2_5',
#  'ask2_5',
#  'ask3_5',
#  'ask3_5',
#  'ask3_5',
#  'ask4_5',
#  'ask4_5',
#  'ask4_5',
#  'ask5_5',
#  'ask5_5',
#  'ask5_5',
#  'ask6_5',
#  'ask6_5',
#  'price6',
#  'bid0_6',
#  'bid0_6',
#  'bid0_6',
#  'bid1_6',
#  'bid1_6',
#  'bid1_6',
#  'bid2_6',
#  'bid2_6',
#  'bid2_6',
#  'bid3_6',
#  'bid3_6',
#  'bid3_6',
#  'bid4_6',
#  'bid4_6',
#  'bid4_6',
#  'bid5_6',
#  'bid5_6',
#  'bid5_6',
#  'bid6_6',
#  'bid6_6',
#  'ask0_6',
#  'ask0_6',
#  'ask0_6',
#  'ask1_6',
#  'ask1_6',
#  'ask1_6',
#  'ask2_6',
#  'ask2_6',
#  'ask2_6',
#  'ask3_6',
#  'ask3_6',
#  'ask3_6',
#  'ask4_6',
#  'ask4_6',
#  'ask4_6',
#  'ask5_6',
#  'ask5_6',
#  'ask5_6',
#  'ask6_6',
#  'ask6_6',
#  'price7',
#  'bid0_7',
#  'bid0_7',
#  'bid0_7',
#  'bid1_7',
#  'bid1_7',
#  'bid1_7',
#  'bid2_7',
#  'bid2_7',
#  'bid2_7',
#  'bid3_7',
#  'bid3_7',
#  'bid3_7',
#  'bid4_7',
#  'bid4_7',
#  'bid4_7',
#  'bid5_7',
#  'bid5_7',
#  'bid5_7',
#  'bid6_7',
#  'bid6_7',
#  'ask0_7',
#  'ask0_7',
#  'ask0_7',
#  'ask1_7',
#  'ask1_7',
#  'ask1_7',
#  'ask2_7',
#  'ask2_7',
#  'ask2_7',
#  'ask3_7',
#  'ask3_7',
#  'ask3_7',
#  'ask4_7',
#  'ask4_7',
#  'ask4_7',
#  'ask5_7',
#  'ask5_7',
#  'ask5_7',
#  'ask6_7',
#  'ask6_7',
#  'price8',
#  'bid0_8',
#  'bid0_8',
#  'bid0_8',
#  'bid1_8',
#  'bid1_8',
#  'bid1_8',
#  'bid2_8',
#  'bid2_8',
#  'bid2_8',
#  'bid3_8',
#  'bid3_8',
#  'bid3_8',
#  'bid4_8',
#  'bid4_8',
#  'bid4_8',
#  'bid5_8',
#  'bid5_8',
#  'bid5_8',
#  'bid6_8',
#  'bid6_8',
#  'ask0_8',
#  'ask0_8',
#  'ask0_8',
#  'ask1_8',
#  'ask1_8',
#  'ask1_8',
#  'ask2_8',
#  'ask2_8',
#  'ask2_8',
#  'ask3_8',
#  'ask3_8',
#  'ask3_8',
#  'ask4_8',
#  'ask4_8',
#  'ask4_8',
#  'ask5_8',
#  'ask5_8',
#  'ask5_8',
#  'ask6_8',
#  'ask6_8',
#  'price9',
#  'bid0_9',
#  'bid0_9',
#  'bid0_9',
#  'bid1_9',
#  'bid1_9',
#  'bid1_9',
#  'bid2_9',
#  'bid2_9',
#  'bid2_9',
#  'bid3_9',
#  'bid3_9',
#  'bid3_9',
#  'bid4_9',
#  'bid4_9',
#  'bid4_9',
#  'bid5_9',
#  'bid5_9',
#  'bid5_9',
#  'bid6_9',
#  'bid6_9',
#  'ask0_9',
#  'ask0_9',
#  'ask0_9',
#  'ask1_9',
#  'ask1_9',
#  'ask1_9',
#  'ask2_9',
#  'ask2_9',
#  'ask2_9',
#  'ask3_9',
#  'ask3_9',
#  'ask3_9',
#  'ask4_9',
#  'ask4_9',
#  'ask4_9',
#  'ask5_9',
#  'ask5_9',
#  'ask5_9',
#  'ask6_9',
#  'ask6_9',
#  'price10',
#  'bid0_10',
#  'bid0_10',
#  'bid0_10',
#  'bid1_10',
#  'bid1_10',
#  'bid1_10',
#  'bid2_10',
#  'bid2_10',
#  'bid2_10',
#  'bid3_10',
#  'bid3_10',
#  'bid3_10',
#  'bid4_10',
#  'bid4_10',
#  'bid4_10',
#  'bid5_10',
#  'bid5_10',
#  'bid5_10',
#  'bid6_10',
#  'bid6_10',
#  'ask0_10',
#  'ask0_10',
#  'ask0_10',
#  'ask1_10',
#  'ask1_10',
#  'ask1_10',
#  'ask2_10',
#  'ask2_10',
#  'ask2_10',
#  'ask3_10',
#  'ask3_10',
#  'ask3_10',
#  'ask4_10',
#  'ask4_10',
#  'ask4_10',
#  'ask5_10',
#  'ask5_10',
#  'ask5_10',
#  'ask6_10',
#  'ask6_10',
#  'price11',
#  'bid0_11',
#  'bid0_11',
#  'bid0_11',
#  'bid1_11',
#  'bid1_11',
#  'bid1_11',
#  'bid2_11',
#  'bid2_11',
#  'bid2_11',
#  'bid3_11',
#  'bid3_11',
#  'bid3_11',
#  'bid4_11',
#  'bid4_11',
#  'bid4_11',
#  'bid5_11',
#  'bid5_11',
#  'bid5_11',
#  'bid6_11',
#  'bid6_11',
#  'ask0_11',
#  'ask0_11',
#  'ask0_11',
#  'ask1_11',
#  'ask1_11',
#  'ask1_11',
#  'ask2_11',
#  'ask2_11',
#  'ask2_11',
#  'ask3_11',
#  'ask3_11',
#  'ask3_11',
#  'ask4_11',
#  'ask4_11',
#  'ask4_11',
#  'ask5_11',
#  'ask5_11',
#  'ask5_11',
#  'ask6_11',
#  'ask6_11',
#  'price12',
#  'bid0_12',
#  'bid0_12',
#  'bid0_12',
#  'bid1_12',
#  'bid1_12',
#  'bid1_12',
#  'bid2_12',
#  'bid2_12',
#  'bid2_12',
#  'bid3_12',
#  'bid3_12',
#  'bid3_12',
#  'bid4_12',
#  'bid4_12',
#  'bid4_12',
#  'bid5_12',
#  'bid5_12',
#  'bid5_12',
#  'bid6_12',
#  'bid6_12',
#  'ask0_12',
#  'ask0_12',
#  'ask0_12',
#  'ask1_12',
#  'ask1_12',
#  'ask1_12',
#  'ask2_12',
#  'ask2_12',
#  'ask2_12',
#  'ask3_12',
#  'ask3_12',
#  'ask3_12',
#  'ask4_12',
#  'ask4_12',
#  'ask4_12',
#  'ask5_12',
#  'ask5_12',
#  'ask5_12',
#  'ask6_12',
#  'ask6_12',
#  'price13',
#  'bid0_13',
#  'bid0_13',
#  'bid0_13',
#  'bid1_13',
#  'bid1_13',
#  'bid1_13',
#  'bid2_13',
#  'bid2_13',
#  'bid2_13',
#  'bid3_13',
#  'bid3_13',
#  'bid3_13',
#  'bid4_13',
#  'bid4_13',
#  'bid4_13',
#  'bid5_13',
#  'bid5_13',
#  'bid5_13',
#  'bid6_13',
#  'bid6_13',
#  'ask0_13',
#  'ask0_13',
#  'ask0_13',
#  'ask1_13',
#  'ask1_13',
#  'ask1_13',
#  'ask2_13',
#  'ask2_13',
#  'ask2_13',
#  'ask3_13',
#  'ask3_13',
#  'ask3_13',
#  'ask4_13',
#  'ask4_13',
#  'ask4_13',
#  'ask5_13',
#  'ask5_13',
#  'ask5_13',
#  'ask6_13',
#  'ask6_13',
#  'price14',
#  'bid0_14',
#  'bid0_14',
#  'bid0_14',
#  'bid1_14',
#  'bid1_14',
#  'bid1_14',
#  'bid2_14',
#  'bid2_14',
#  'bid2_14',
#  'bid3_14',
#  'bid3_14',
#  'bid3_14',
#  'bid4_14',
#  'bid4_14',
#  'bid4_14',
#  'bid5_14',
#  'bid5_14',
#  'bid5_14',
#  'bid6_14',
#  'bid6_14',
#  'ask0_14',
#  'ask0_14',
#  'ask0_14',
#  'ask1_14',
#  'ask1_14',
#  'ask1_14',
#  'ask2_14',
#  'ask2_14',
#  'ask2_14',
#  'ask3_14',
#  'ask3_14',
#  'ask3_14',
#  'ask4_14',
#  'ask4_14',
#  'ask4_14',
#  'ask5_14',
#  'ask5_14',
#  'ask5_14',
#  'ask6_14',
#  'ask6_14',
#  'price15',
#  'bid0_15',
#  'bid0_15',
#  'bid0_15',
#  'bid1_15',
#  'bid1_15',
#  'bid1_15',
#  'bid2_15',
#  'bid2_15',
#  'bid2_15',
#  'bid3_15',
#  'bid3_15',
#  'bid3_15',
#  'bid4_15',
#  'bid4_15',
#  'bid4_15',
#  'bid5_15',
#  'bid5_15',
#  'bid5_15',
#  'bid6_15',
#  'bid6_15',
#  'ask0_15',
#  'ask0_15',
#  'ask0_15',
#  'ask1_15',
#  'ask1_15',
#  'ask1_15',
#  'ask2_15',
#  'ask2_15',
#  'ask2_15',
#  'ask3_15',
#  'ask3_15',
#  'ask3_15',
#  'ask4_15',
#  'ask4_15',
#  'ask4_15',
#  'ask5_15',
#  'ask5_15',
#  'ask5_15',
#  'ask6_15',
#  'ask6_15',
#  'price16',
#  'bid0_16',
#  'bid0_16',
#  'bid0_16',
#  'bid1_16',
#  'bid1_16',
#  'bid1_16',
#  'bid2_16',
#  'bid2_16',
#  'bid2_16',
#  'bid3_16',
#  'bid3_16',
#  'bid3_16',
#  'bid4_16',
#  'bid4_16',
#  'bid4_16',
#  'bid5_16',
#  'bid5_16',
#  'bid5_16',
#  'bid6_16',
#  'bid6_16',
#  'ask0_16',
#  'ask0_16',
#  'ask0_16',
#  'ask1_16',
#  'ask1_16',
#  'ask1_16',
#  'ask2_16',
#  'ask2_16',
#  'ask2_16',
#  'ask3_16',
#  'ask3_16',
#  'ask3_16',
#  'ask4_16',
#  'ask4_16',
#  'ask4_16',
#  'ask5_16',
#  'ask5_16',
#  'ask5_16',
#  'ask6_16',
#  'ask6_16',
#  'price17',
#  'bid0_17',
#  'bid0_17',
#  'bid0_17',
#  'bid1_17',
#  'bid1_17',
#  'bid1_17',
#  'bid2_17',
#  'bid2_17',
#  'bid2_17',
#  'bid3_17',
#  'bid3_17',
#  'bid3_17',
#  'bid4_17',
#  'bid4_17',
#  'bid4_17',
#  'bid5_17',
#  'bid5_17',
#  'bid5_17',
#  'bid6_17',
#  'bid6_17',
#  'ask0_17',
#  'ask0_17',
#  'ask0_17',
#  'ask1_17',
#  'ask1_17',
#  'ask1_17',
#  'ask2_17',
#  'ask2_17',
#  'ask2_17',
#  'ask3_17',
#  'ask3_17',
#  'ask3_17',
#  'ask4_17',
#  'ask4_17',
#  'ask4_17',
#  'ask5_17',
#  'ask5_17',
#  'ask5_17',
#  'ask6_17',
#  'ask6_17',
#  'price18',
#  'bid0_18',
#  'bid0_18',
#  'bid0_18',
#  'bid1_18',
#  'bid1_18',
#  'bid1_18',
#  'bid2_18',
#  'bid2_18',
#  'bid2_18',
#  'bid3_18',
#  'bid3_18',
#  'bid3_18',
#  'bid4_18',
#  'bid4_18',
#  'bid4_18',
#  'bid5_18',
#  'bid5_18',
#  'bid5_18',
#  'bid6_18',
#  'bid6_18',
#  'ask0_18',
#  'ask0_18',
#  'ask0_18',
#  'ask1_18',
#  'ask1_18',
#  'ask1_18',
#  'ask2_18',
#  'ask2_18',
#  'ask2_18',
#  'ask3_18',
#  'ask3_18',
#  'ask3_18',
#  'ask4_18',
#  'ask4_18',
#  'ask4_18',
#  'ask5_18',
#  'ask5_18',
#  'ask5_18',
#  'ask6_18',
#  'ask6_18',
#  'price19',
#  'bid0_19',
#  'bid0_19',
#  'bid0_19',
#  'bid1_19',
#  'bid1_19',
#  'bid1_19',
#  'bid2_19',
#  'bid2_19',
#  'bid2_19',
#  'bid3_19',
#  'bid3_19',
#  'bid3_19',
#  'bid4_19',
#  'bid4_19',
#  'bid4_19',
#  'bid5_19',
#  'bid5_19',
#  'bid5_19',
#  'bid6_19',
#  'bid6_19',
#  'ask0_19',
#  'ask0_19',
#  'ask0_19',
#  'ask1_19',
#  'ask1_19',
#  'ask1_19',
#  'ask2_19',
#  'ask2_19',
#  'ask2_19',
#  'ask3_19',
#  'ask3_19',
#  'ask3_19',
#  'ask4_19',
#  'ask4_19',
#  'ask4_19',
#  'ask5_19',
#  'ask5_19',
#  'ask5_19',
#  'ask6_19',
#  'ask6_19']

# %%
print(1) if 0 else print(3)
# Out:
# 3

# %%
def normalize(df, label=True):
     = df.shape[0]
# Out:
#   File "<ipython-input-6-e14f62587a11>", line 1
#     df.groupby(, axis=1)
#                ^
# SyntaxError: invalid syntax
